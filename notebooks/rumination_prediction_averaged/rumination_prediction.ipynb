# %% [markdown]
# # Rumination prediction - averaged participants' epochs

# %% [markdown]
# ### Imports

# %%
# %load_ext lab_black
import os
import pickle
from time import time
import pywt
import mne
import scipy
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import cesium.featurize
from plotly.subplots import make_subplots
from ipywidgets import Dropdown, FloatRangeSlider, IntSlider, FloatSlider, interact
from sklearn.decomposition import FastICA
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA
from sklearn.base import TransformerMixin, BaseEstimator


import sys

sys.path.append("..")
from utils import *

# %% [markdown]
# ### Loading data

# %% [markdown]
# Loading EEG data and data from rumination questionnaire. By default create_df_data loads all info from given file but one can specify it by passing a list of desired labels from csv file.

# %%
tmin, tmax = -0.1, 0.6
signal_frequency = 256
ERROR = 0
CORRECT = 1
random_state = 0

# %%
channels_order_list = [
    "Fp1",
    "AF7",
    "AF3",
    "F1",
    "F3",
    "F5",
    "F7",
    "FT7",
    "FC5",
    "FC3",
    "FC1",
    "C1",
    "C3",
    "C5",
    "T7",
    "TP7",
    "CP5",
    "CP3",
    "CP1",
    "P1",
    "P3",
    "P5",
    "P7",
    "P9",
    "PO7",
    "PO3",
    "O1",
    "Iz",
    "Oz",
    "POz",
    "Pz",
    "CPz",
    "Fpz",
    "Fp2",
    "AF8",
    "AF4",
    "AFz",
    "Fz",
    "F2",
    "F4",
    "F6",
    "F8",
    "FT8",
    "FC6",
    "FC4",
    "FC2",
    "FCz",
    "Cz",
    "C2",
    "C4",
    "C6",
    "T8",
    "TP8",
    "CP6",
    "CP4",
    "CP2",
    "P2",
    "P4",
    "P6",
    "P8",
    "P10",
    "PO8",
    "PO4",
    "O2",
]

# %%
channels_dict = dict(zip(channels_order_list, np.arange(1, 64, 1)))

# %% [markdown]
# Define significant channels - the rest will be excluded

# %%
red_box = [
    "F1",
    "Fz",
    "F2",
    "FC1",
    "FCz",
    "FC2",
    "C1",
    "Cz",
    "C2",
    "CP1",
    "CPz",
    "CP2",
    "P1",
    "Pz",
    "P2",
]
significant_channels = [channels_dict[channel] for channel in red_box]

# %% [markdown]
# Read the data

# %%
df_name = "go_nogo_df_mean"
pickled_data_filename = "../../data/" + df_name + ".pkl"
info_filename = "../../data/Demographic_Questionnaires_Behavioral_Results_N=163.csv"

# Check if data is already loaded
if os.path.isfile(pickled_data_filename):
    print("Pickled file found. Loading pickled data...")
    epochs_df = pd.read_pickle(pickled_data_filename)
    print("Done")
else:
    print("Pickled file not found. Loading data...")
    epochs_df = create_df_data(
        test_participants=False, info="all", personal=False, info_filename=info_filename
    )
    epochs_df.name = df_name
    # save loaded data into a pickle file
    epochs_df.to_pickle("../../data/" + epochs_df.name + ".pkl")
    print("Done. Pickle file created")
# Out:
# Pickled file not found. Loading data...
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AR0607-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AR0607-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 50 bad epochs dropped
# AR0607
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_HN2708-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_HN2708-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 264 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 264 events and 181 original time points ...
# 49 bad epochs dropped
# HN2708
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MK1007-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MK1007-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 271 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 271 events and 181 original time points ...
# 46 bad epochs dropped
# MK1007
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AO2010-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AO2010-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# ../utils.py:131: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_brainvision(file)
# ../utils.py:140: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw.set_annotations(annotations)
# 103 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JL2111-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JL2111-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 277 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 277 events and 181 original time points ...
# 185 bad epochs dropped
# JL2111
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MZ0502-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MZ0502-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 233 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 233 events and 181 original time points ...
# 211 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AK2308-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AK2308-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 235 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 235 events and 181 original time points ...
# 109 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IG0308-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IG0308-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 23 bad epochs dropped
# IG0308
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MB1610-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MB1610-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 38 bad epochs dropped
# MB1610
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_BZ1004-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_BZ1004-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 262 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 262 events and 181 original time points ...
# 143 bad epochs dropped
# BZ1004
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AP0706-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AP0706-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 227 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 227 events and 181 original time points ...
# 131 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MD2903-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MD2903-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 248 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 248 events and 181 original time points ...
# 33 bad epochs dropped
# MD2903
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_PS1511-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_PS1511-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 233 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 233 events and 181 original time points ...
# 19 bad epochs dropped
# PS1511
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MW1710-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MW1710-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 39 bad epochs dropped
# MW1710
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_RS0303-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_RS0303-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 252 events and 181 original time points ...
# 35 bad epochs dropped
# RS0303
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MB2105-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MB2105-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 196 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AS0401-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AS0401-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 230 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 230 events and 181 original time points ...
# 24 bad epochs dropped
# AS0401
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MK1711-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MK1711-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 269 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 269 events and 181 original time points ...
# 116 bad epochs dropped
# MK1711
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KM0312-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KM0312-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 87 bad epochs dropped
# KM0312
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IS0103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IS0103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 253 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 253 events and 181 original time points ...
# 29 bad epochs dropped
# IS0103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MB0503-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MB0503-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 257 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 257 events and 181 original time points ...
# 107 bad epochs dropped
# MB0503
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AN2907-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AN2907-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 275 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 275 events and 181 original time points ...
# 44 bad epochs dropped
# AN2907
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KS2404-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KS2404-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 252 events and 181 original time points ...
# 63 bad epochs dropped
# KS2404
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AS2008-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AS2008-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 86 bad epochs dropped
# AS2008
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_PW2803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_PW2803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 245 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 245 events and 181 original time points ...
# 94 bad epochs dropped
# PW2803
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JP1201-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JP1201-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 312 events and 181 original time points ...
# 184 bad epochs dropped
# JP1201
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MC1506-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MC1506-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 22 bad epochs dropped
# MC1506
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AB0612-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AB0612-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 262 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 262 events and 181 original time points ...
# 12 bad epochs dropped
# AB0612
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IB1704-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IB1704-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 218 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 218 events and 181 original time points ...
# 66 bad epochs dropped
# IB1704
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KS2803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KS2803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 84 bad epochs dropped
# KS2803
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KK1110-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KK1110-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 243 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 243 events and 181 original time points ...
# 6 bad epochs dropped
# KK1110
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DJ0205-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DJ0205-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 181 original time points ...
# 204 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AI2201-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AI2201-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 222 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 222 events and 181 original time points ...
# 211 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JZ0904-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JZ0904-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 245 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 245 events and 181 original time points ...
# 187 bad epochs dropped
# JZ0904
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_VZ0501-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_VZ0501-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 239 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 239 events and 181 original time points ...
# 103 bad epochs dropped
# VZ0501
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KS3101-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KS3101-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 271 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 271 events and 181 original time points ...
# 87 bad epochs dropped
# KS3101
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MP0407-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MP0407-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 247 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 247 events and 181 original time points ...
# 64 bad epochs dropped
# MP0407
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_RJ1803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_RJ1803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 34 bad epochs dropped
# RJ1803
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MW1508-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MW1508-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 181 original time points ...
# 37 bad epochs dropped
# MW1508
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_NB1103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_NB1103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 239 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 239 events and 181 original time points ...
# 67 bad epochs dropped
# NB1103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DP2901-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DP2901-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 241 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 241 events and 181 original time points ...
# 55 bad epochs dropped
# DP2901
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MD1502-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MD1502-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 255 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 255 events and 181 original time points ...
# 187 bad epochs dropped
# MD1502
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KK0110-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KK0110-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 249 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 249 events and 181 original time points ...
# 46 bad epochs dropped
# KK0110
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JG0702-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JG0702-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 60 bad epochs dropped
# JG0702
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MC1404-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MC1404-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 229 events and 181 original time points ...
# 43 bad epochs dropped
# MC1404
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MC1606-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MC1606-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 263 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 263 events and 181 original time points ...
# 69 bad epochs dropped
# MC1606
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JM2103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JM2103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 253 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 253 events and 181 original time points ...
# 225 bad epochs dropped
# JM2103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DP2803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DP2803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 229 events and 181 original time points ...
# 228 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DP1905-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DP1905-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 244 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 244 events and 181 original time points ...
# 4 bad epochs dropped
# DP1905
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AK1312-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AK1312-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 260 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 260 events and 181 original time points ...
# 221 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MK1506-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MK1506-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 132 bad epochs dropped
# MK1506
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AP2105-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AP2105-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 123 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MM1112-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MM1112-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 235 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 235 events and 181 original time points ...
# 13 bad epochs dropped
# MM1112
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AO2601-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AO2601-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# ../utils.py:131: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_brainvision(file)
# ../utils.py:140: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw.set_annotations(annotations)
# 146 bad epochs dropped
# AO2601
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AK2012-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AK2012-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 262 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 262 events and 181 original time points ...
# 167 bad epochs dropped
# AK2012
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KD1102-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KD1102-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 224 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 224 events and 181 original time points ...
# 71 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_FK0508-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_FK0508-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 181 original time points ...
# 44 bad epochs dropped
# FK0508
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KB0101-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KB0101-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 265 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 265 events and 181 original time points ...
# 72 bad epochs dropped
# KB0101
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AC2011-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AC2011-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 67 bad epochs dropped
# AC2011
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_ZW2709-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_ZW2709-64 el.vhdr
# ...
# Not setting metadata
# Not setting metadata
# 294 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 294 events and 181 original time points ...
# 258 bad epochs dropped
# WC0301
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JS0303-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JS0303-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 250 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 250 events and 181 original time points ...
# 166 bad epochs dropped
# JS0303
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KB2309-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KB2309-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 248 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 248 events and 181 original time points ...
# 103 bad epochs dropped
# KB2309
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AR1506-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AR1506-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 258 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 258 events and 181 original time points ...
# 100 bad epochs dropped
# AR1506
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KJ1811-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KJ1811-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 236 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 236 events and 181 original time points ...
# 76 bad epochs dropped
# KJ1811
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_TT2311-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_TT2311-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 268 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 268 events and 181 original time points ...
# 191 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_TZ2302-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_TZ2302-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 247 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 247 events and 181 original time points ...
# ../utils.py:131: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_brainvision(file)
# ../utils.py:140: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw.set_annotations(annotations)
# 72 bad epochs dropped
# TZ2302
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_BW1003-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_BW1003-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 251 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 251 events and 181 original time points ...
# 21 bad epochs dropped
# BW1003
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IA2105-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_IA2105-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 241 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 241 events and 181 original time points ...
# 29 bad epochs dropped
# IA2105
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_PD0809-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_PD0809-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 264 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 264 events and 181 original time points ...
# 38 bad epochs dropped
# PD0809
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KN1606-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KN1606-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 247 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 247 events and 181 original time points ...
# 131 bad epochs dropped
# KN1606
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JM3011-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JM3011-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 283 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 283 events and 181 original time points ...
# 94 bad epochs dropped
# JM3011
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KM2404-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_KM2404-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 81 bad epochs dropped
# KM2404
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_BB1406-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_BB1406-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 239 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 239 events and 181 original time points ...
# 125 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AP0601-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AP0601-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 133 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AG1511-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_AG1511-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 229 events and 181 original time points ...
# 83 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MA0706-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MA0706-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 260 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 260 events and 181 original time points ...
# 32 bad epochs dropped
# MA0706
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JM0103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_JM0103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 252 events and 181 original time points ...
# 47 bad epochs dropped
# JM0103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MJ1306-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_MJ1306-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 254 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 254 events and 181 original time points ...
# 66 bad epochs dropped
# MJ1306
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DO0607-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/notebooks/../data/responses/GNG_DO0607-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 27 bad epochs dropped
# DO0607
# Done. Pickle file created

# %% [markdown]
# #### Rearrange data: each row is one participant; epochs column contain list of epochs from given condition (marker = error or correct)

# %%
data_df = (
    epochs_df.groupby(
        ["id", "marker"],
        sort=False,
    )
    .apply(
        lambda group_df: pd.Series(
            {
                "epochs": np.array(group_df["epoch"].to_list()),
                "Rumination Full Scale": np.mean(group_df["Rumination Full Scale"]),
            }
        )
    )
    .reset_index()
)

# %%
averaged_epochs_df = (
    epochs_df.groupby(
        ["id", "marker"],
        sort=False,
    )
    .apply(
        lambda group_df: pd.Series(
            {
                "epoch": np.mean(group_df["epoch"]),
                "Rumination Full Scale": np.mean(group_df["Rumination Full Scale"]),
            }
        )
    )
    .reset_index()
)

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ## Training and predictions

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from tempfile import mkdtemp
from sklearn.linear_model import Ridge
from sklearn.kernel_ridge import KernelRidge

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import warnings

warnings.filterwarnings("ignore")


import numpy as np
import scipy.stats

# %% [markdown]
# #### Standard features for EEG analysis provided by Guo et al. (2012)

# %%
def std_signal(t, m, e):
    return np.std(m)


def abs_diffs_signal(t, m, e):
    return np.sum(np.abs(np.diff(m)))


def mean_energy_signal(t, m, e):
    return np.mean(m ** 2)


def skew_signal(t, m, e):
    return scipy.stats.skew(m)


def mean_signal(t, m, e):
    return np.mean(m)

# %%
guo_features = {
    "mean": mean_signal,
    "std": std_signal,
    "mean_energy": mean_energy_signal,
}

step_in_ms = 50
step_tp = int(signal_frequency * step_in_ms / 1000)

# %% [markdown]
# #### Calculate p-value with permutation test

# %%
from sklearn.model_selection import permutation_test_score


def calculate_p_permutations(estimator, X, y, cv=3, n_permutations=100, n_jobs=10):

    score_, perm_scores_, pvalue_ = permutation_test_score(
        estimator, X, y, cv=cv, n_permutations=n_permutations, n_jobs=n_jobs
    )

    # summarize
    print(f"     The permutation P-value is = {pvalue_:.3f}")
    print(f"     The permutation score is = {score_:.3f}\n")

    return score_, pvalue_

# %% [markdown]
# #### Validation curves - for parameters' insight

# %%
import matplotlib.pyplot as plt


def pooled_var(stds):
    # https://en.wikipedia.org/wiki/Pooled_variance#Pooled_standard_deviation
    n = 5  # size of each group
    return np.sqrt(sum((n - 1) * (stds ** 2)) / len(stds) * (n - 1))


def show_validation_curves(cv_results, grid_params):

    df = pd.DataFrame(cv_results)
    results = [
        "mean_test_r2",
        "mean_train_r2",
        "std_test_r2",
        "std_train_r2",
    ]

    fig, axes = plt.subplots(
        1, len(grid_params), figsize=(5 * len(grid_params), 7), sharey="row"
    )
    axes[0].set_ylabel("Score", fontsize=25)

    for idx, (param_name, param_range) in enumerate(grid_params.items()):
        grouped_df = df.groupby(f"param_{param_name}")[results].agg(
            {
                "mean_train_r2": "mean",
                "mean_test_r2": "mean",
                "std_train_r2": pooled_var,
                "std_test_r2": pooled_var,
            }
        )

        previous_group = df.groupby(f"param_{param_name}")[results]
        axes[idx].set_xlabel(param_name, fontsize=10)
        axes[idx].set_ylim(0.0, 1.1)
        axes[idx].set_xscale("log")
        lw = 2
        axes[idx].plot(
            param_range,
            grouped_df["mean_train_r2"],
            label="Training score",
            color="darkorange",
            lw=lw,
        )
        axes[idx].fill_between(
            param_range,
            grouped_df["mean_train_r2"] - grouped_df["std_train_r2"],
            grouped_df["mean_train_r2"] + grouped_df["std_train_r2"],
            alpha=0.2,
            color="darkorange",
            lw=lw,
        )
        axes[idx].plot(
            param_range,
            grouped_df["mean_test_r2"],
            label="Cross-validation score",
            color="navy",
            lw=lw,
        )
        axes[idx].fill_between(
            param_range,
            grouped_df["mean_test_r2"] - grouped_df["std_test_r2"],
            grouped_df["mean_test_r2"] + grouped_df["std_test_r2"],
            alpha=0.2,
            color="navy",
            lw=lw,
        )

    handles, labels = axes[0].get_legend_handles_labels()
    fig.suptitle("Validation curves", fontsize=40)
    fig.legend(handles, labels, loc=8, ncol=2, fontsize=20)

    fig.subplots_adjust(bottom=0.25, top=0.85)
    plt.show()

# %% [markdown]
# ----------------------------------------

# %% [markdown]
# ### Create X and y sets

# %%
dataset = ERROR
dataset_name = "correct" if dataset == CORRECT else "error"

# %%
X_train = np.array(
    # averaged_epochs_df[averaged_epochs_df["marker"] == dataset]["epoch"].to_list()
    averaged_epochs_df[averaged_epochs_df["marker"] == dataset]["epoch"].to_list()
)
y_train = np.array(
    # averaged_epochs_df[averaged_epochs_df["marker"] == dataset][
    #     "Rumination Full Scale"
    # ].to_list()
    averaged_epochs_df[averaged_epochs_df["marker"] == dataset][
        "Rumination Full Scale"
    ].to_list()
)

# X_train = np.array(data_df[data_df["marker"] == dataset]["epochs"].tolist())
# y_train = np.array(
#     data_df[data_df["marker"] == dataset]["Rumination Full Scale"].to_list()
# )

# %%
X_test = []
y_test = []

# %%
y_train.shape
# Out:
# (108,)

# %% [markdown]
# ----------------------------

# %% [markdown]
# ### Define searching experiment

# %%
def rate_regressor(
    X_train, y_train, X_test, y_test, regressor, regressor_params, base_steps, cv=2
):
    # define cross-validation method
    cv_kf = KFold(n_splits=3)

    pipeline = Pipeline(steps=base_steps + [regressor])
    param_grid = regressor_params
    grid_search = GridSearchCV(
        pipeline,
        param_grid,
        cv=cv_kf,
        scoring={"r2", "neg_mean_absolute_error"},
        refit="r2",
        return_train_score=True,
        n_jobs=4,
        verbose=1,
    )
    grid_search.fit(X_train, y_train)

    return grid_search

# %%
def run_experiment(
    tested_regressors,
    regressor_params,
    pipeline_name,
    X_train,
    X_test,
    y_train,
    y_test,
    dataset_name,
    base_steps,
    results_df,
    #     function_name="-",
):

    for (regressor, params) in tested_regressors:
        print(f"Rating {regressor} \n")
        tested_params = {**regressor_params, **params}

        grid_result = rate_regressor(
            X_train,
            y_train,
            X_test,
            y_test,
            regressor,
            tested_params,
            base_steps,
            cv=3,
        )

        #     predictions = grid_result.predict(X_test)
        #     r2 = grid_result.score(X_test, y_test)
        #     mae = mean_absolute_error(y_test, predictions)
        #     r2_adj = r2_adjusted_scorer(y_test, predictions, len(X_test[0]), len(X_test))

        best_estimator_index = grid_result.best_index_
        mean_cv_r2 = grid_result.cv_results_["mean_test_r2"][best_estimator_index]
        std_cv_r2 = grid_result.cv_results_["std_test_r2"][best_estimator_index]
        mean_cv_neg_mean_absolute_error = grid_result.cv_results_[
            "mean_test_neg_mean_absolute_error"
        ][best_estimator_index]
        std_cv_neg_mean_absolute_error = grid_result.cv_results_[
            "std_test_neg_mean_absolute_error"
        ][best_estimator_index]
        mean_train_r2 = grid_result.cv_results_["mean_train_r2"][best_estimator_index]

        print(f"     Best parameters: {grid_result.best_params_}")
        print(f"     mean r2: {mean_cv_r2}           ± {round(std_cv_r2,3)}")
        print(f"     mean r2 train: {mean_train_r2}")

        cv_results = grid_result.cv_results_
        #         t_statistics, p_value = calculate_p(
        #             grid_result.best_estimator_, X_train, y_train
        #         )
        scores_, pvalue_ = calculate_p_permutations(
            grid_result.best_estimator_, X_train, y_train
        )

        #         show_validation_curves(grid_result.cv_results_, tested_params)

        data = {
            "data_set": dataset_name,
            "pipeline_name": pipeline_name,
            #             "function": function_name,
            "model": regressor[0],
            "parameters": grid_result.best_params_,
            "mean_cv_r2": mean_cv_r2,
            "std_cv_r2": std_cv_r2,
            "mean_cv_mae": mean_cv_neg_mean_absolute_error,
            "std_cv_mae": std_cv_neg_mean_absolute_error,
            "cv_results": cv_results,
            "mean_train_r2": mean_train_r2,
            "p-value": pvalue_,
            "best_estimator": grid_result.best_estimator_,
        }

        results_df = results_df.append(data, ignore_index=True)
    return results_df

# %% [markdown]
# ---------------------

# %% [markdown]
# ### Define data transformers - custom data transformation steps

# %%
from __future__ import division
from scipy.signal import butter, lfilter


class LowpassFilter(TransformerMixin, BaseEstimator):
    def __init__(self):
        super().__init__()

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        fs = signal_frequency
        cutoff = 45  # Hz
        B, A = butter(
            6, cutoff / (fs / 2), btype="low", analog=False
        )  # 6th order Butterworth low-pass

        filtered_epochs_per_channel = []
        for channel in X:
            filtered_epochs = np.array(
                [lfilter(B, A, epoch, axis=0) for epoch in channel]
            )
            filtered_epochs_per_channel.append(filtered_epochs)
        filtered_epochs_per_channel = np.array(filtered_epochs_per_channel)
        print(
            # f"IN BUTTERWORTH FILTER SHAPE: {filtered_epochs_per_channel.shape} ; SIGNAL: {filtered_epochs.shape}\n"
        )
        return filtered_epochs_per_channel


class IcaPreprocessing(TransformerMixin, BaseEstimator):
    def __init__(self):
        super().__init__()

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        timepoints_per_channel = np.concatenate(X, axis=1)
        return timepoints_per_channel.T


class IcaPostprocessing(TransformerMixin, BaseEstimator):
    def __init__(self, timepoints_count):
        super().__init__()
        self.timepoints_count = timepoints_count

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_ica_transposed = X.T
        ica_n_components = X.shape[1]

        epochs_count = int(X_ica_transposed.shape[1] / self.timepoints_count)
        data_per_channel = X_ica_transposed.reshape(
            ica_n_components, epochs_count, self.timepoints_count
        )

        return data_per_channel


class Cwt(TransformerMixin, BaseEstimator):
    def __init__(self, mwt="morl", cwt_density=2, cwt_octaves=6):
        # for octaves=6, the highest frequency is 45.25 Hz
        super().__init__()
        self.mwt = mwt
        self.cwt_density = cwt_density
        self.cwt_octaves = cwt_octaves

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        cwt_per_channel = []
        for data in X:
            data_cwt = np.array(
                [
                    cwt(epoch, self.mwt, self.cwt_density, self.cwt_octaves)
                    for epoch in data
                ]
            )
            cwt_per_channel.append(data_cwt)
        cwt_per_channel = np.array(cwt_per_channel)
        return cwt_per_channel


class CwtFeatureVectorizer(TransformerMixin, BaseEstimator):
    def __init__(self, feature_dict):
        super().__init__()
        self.feature_dict = feature_dict

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        vectorized_data = []
        for data_cwt in X:
            # cesium functions
            feature_set_cwt = cesium.featurize.featurize_time_series(
                times=None,
                values=data_cwt,
                errors=None,
                features_to_use=list(self.feature_dict.keys()),
                custom_functions=self.feature_dict,
            )
            features_per_epoch = feature_set_cwt.to_numpy()
            vectorized_data.append(features_per_epoch)
        vectorized_data = np.array(vectorized_data)
        return vectorized_data


# reshape data from (channels x epoch x features) to (epochs x channles x features)
# and then flatten it to (epoch x channels*features)
class PostprocessingTransformer(TransformerMixin, BaseEstimator):
    def __init__(self):
        super().__init__()

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        vectorized_data = np.stack(X, axis=1)
        epochs_per_channel_feature = vectorized_data.reshape(
            vectorized_data.shape[0], -1
        )
        return epochs_per_channel_feature


class ChannelExtraction(TransformerMixin, BaseEstimator):
    def __init__(self, channel_list):
        super().__init__()
        self.channel_list = channel_list

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        epochs_per_channels = np.transpose(X, (1, 0, 2))
        epochs_per_selected_channels = []

        for channel in self.channel_list:
            this_data = epochs_per_channels[channel]
            epochs_per_selected_channels.append(this_data)

        epochs_per_selected_channels = np.array(epochs_per_selected_channels)
        selected_channels_per_epoch = np.transpose(
            epochs_per_selected_channels, (1, 0, 2)
        )
        #         print(f"EXTRACTION {selected_channels_per_epoch.shape}")
        return selected_channels_per_epoch


# swap channels and epochs axes: from epoch_channel_timepoints to channel_epoch_timepoints and vice versa
class ChannelDataSwap(TransformerMixin, BaseEstimator):
    def __init__(self):
        super().__init__()

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        data_channel_swaped = np.transpose(X, (1, 0, 2))
        return data_channel_swaped


class BinTransformer(TransformerMixin, BaseEstimator):
    def __init__(self, step):
        super().__init__()
        self.step = step

    def bin_epoch(self, epoch):
        new_channels = []
        for channel in epoch:
            bins_channel = []
            index = 0
            while index + self.step < len(channel):
                this_bin = np.mean(channel[index : index + self.step])
                bins_channel.append(this_bin)
                index += self.step
            new_channels.append(bins_channel)
        return new_channels

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        binned_data = np.array([self.bin_epoch(epoch) for epoch in X])
        return binned_data


# transforms energy of each sub-band into relative energy of sub-band
def RelativeEnergyTransformer():
    def transform(X):
        vectorized_data = []

        for epoch in X:
            total_energy_of_epoch = np.sum(epoch)
            sub_band_relative_energies = np.array(
                [(sub_band_energy / total_energy_of_epoch) for sub_band_energy in epoch]
            )
            vectorized_data.append(sub_band_relative_energies)

        vectorized_data = np.array(vectorized_data)
        return vectorized_data

    return FunctionTransformer(func=transform)

# %% [markdown]
# ------------------
# ### Define architectures

# %%
# ICA-bins + ICA-bins-cwt-features


def ica_bins_features_steps(feature_function_dict):

    steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("ica_preprocessing", IcaPreprocessing()),
        #         ("ica", FastICA(random_state=random_state)),
        ("spatial_filter", PCA(random_state=random_state)),
        (
            "ica_postprocessing",
            IcaPostprocessing(timepoints_count=X_train.shape[-1]),
        ),
        ("lowpass_filter", LowpassFilter()),
        (
            "features",
            FeatureUnion(
                [
                    (
                        "bins",
                        Pipeline(
                            [
                                ("channel_data_swap", ChannelDataSwap()),
                                ("binning", BinTransformer(step=step_tp)),
                                ("data_channel_swap", ChannelDataSwap()),
                                ("postprocessing_bins", PostprocessingTransformer()),
                            ]
                        ),
                    ),
                    (
                        "functions",
                        Pipeline(
                            [
                                ("cwt", Cwt()),
                                (
                                    "cwt_feature",
                                    CwtFeatureVectorizer(
                                        feature_dict=feature_function_dict
                                    ),
                                ),
                                (
                                    "postprocessing_functions",
                                    PostprocessingTransformer(),
                                ),
                            ]
                        ),
                    ),
                ]
            ),
        ),
        ("scaler", StandardScaler()),
        ("feature_selection", PCA(random_state=random_state)),
    ]

    return steps

# %%
# ERP-bins + ERP-bins-cwt-features


def erp_bins_features_steps(feature_function_dict):

    functions_base_steps = [
        ("cwt", Cwt()),
        (
            "cwt_feature",
            CwtFeatureVectorizer(feature_dict=feature_function_dict),
        ),
        ("postprocessing_func", PostprocessingTransformer()),
    ]
    functions_pipeline = Pipeline(steps=functions_base_steps)

    bins_base_steps = [
        ("data_channel_swap_after_filter", ChannelDataSwap()),
        ("binning", BinTransformer(step=step_tp)),
        ("data_channel_swap", ChannelDataSwap()),
        ("postprocessing_bins", PostprocessingTransformer()),
    ]
    bins_pipeline = Pipeline(steps=bins_base_steps)

    combined_features = FeatureUnion(
        [("bins", bins_pipeline), ("functins", functions_pipeline)]
    )

    steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("data_channel_swap_filter", ChannelDataSwap()),
        ("lowpass_filter", LowpassFilter()),
        ("features", combined_features),
        ("scaler", StandardScaler()),
        ("feature_selection", PCA(random_state=random_state)),
    ]

    return steps

# %%
# ICA-bins


def ica_bins_steps():

    steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("ica_preprocessing", IcaPreprocessing()),
        #         ("ica", FastICA(random_state=random_state)),
        ("spatial_filter", PCA(random_state=random_state)),
        (
            "ica_postprocessing",
            IcaPostprocessing(timepoints_count=X_train.shape[-1]),
        ),
        ("lowpass_filter", LowpassFilter()),
        ("channel_data_swap", ChannelDataSwap()),
        ("binning", BinTransformer(step=step_tp)),
        ("data_channel_swap", ChannelDataSwap()),
        ("postprocessing", PostprocessingTransformer()),
        ("scaler", StandardScaler()),
        ("feature_selection", PCA(random_state=random_state)),
    ]

    return steps

# %%
# Erp-bins
def erp_bins_steps():
    steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("data_channel_swap_filter", ChannelDataSwap()),
        ("lowpass_filter", LowpassFilter()),
        ("data_channel_swap_after_filter", ChannelDataSwap()),
        ("binning", BinTransformer(step=step_tp)),
        ("data_channel_swap", ChannelDataSwap()),
        ("postprocessing", PostprocessingTransformer()),
        ("scaler", StandardScaler()),
        ("feature_selection", PCA(random_state=random_state)),
    ]

    return steps

# %% [markdown]
# Generate estimator HTML representation

# %%
# from sklearn.utils import estimator_html_repr

# with open("my_estimator.html", "w") as f:
#     f.write(estimator_html_repr(Pipeline(this_steps)))

# %% [markdown]
# ----------------------

# %% [markdown]
# # Experiments

# %%
regressor_params = dict(
    spatial_filter__n_components=np.arange(1, 9, 1),
    feature_selection__n_components=np.arange(1, 9, 1),
)

# %% [markdown]
# ### Searching best regularization parameters

# %%
# pipeline_name = "PCA_15_bins"
# this_steps = ica_bins_steps()
# pipeline_name = "PCA_4_bins"
# this_steps = ica_bins_steps()

# %%
# pipeline_name = "ERP_bins"
# this_steps = erp_bins_steps()

# %%
# pipeline_name = "PCA_15_bins_functions"
# this_steps = ica_bins_features_steps(guo_features)

# %%
mgr_results = pd.read_pickle("../../public_data/regression_PCA_error.pkl")

# %%
mgr_results

# %%
en = ("en", ElasticNet(random_state=random_state))
en_params = dict(
    en__alpha=np.logspace(-7, 3, num=20, base=10),
    en__l1_ratio=np.logspace(-8, 0, num=17, base=10),
)

tested_regressors = [
    # (svr, svr_params),
    # (kr, kr_params),
    (en, en_params)
]

# %%
results_averaged_nonstatic = pd.DataFrame()

# %%
# for n_components in range(1, 8, 1):

pipeline_name = f"PCA_averaged_nonstatic"
this_steps = ica_bins_steps()
#     pre_processing_pipeline = Pipeline(steps=this_steps)

#     # perform pre-processing
#     pre_processed_X = pre_processing_pipeline.fit_transform(X_train)

#     regressor_steps = [("feature_selection", PCA(random_state=random_state))]

#     for alpha in [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.2, 0.3, 0.4]:
#         for l1_ratio in [
#             0.0000001,
#             0.000001,
#             0.00001,
#             0.0001,
#             0.001,
#             0.01,
#             0.1,
#             0.3,
#             0.5,
#             0.7,
#             1,
#         ]:

#             en = ("en", ElasticNet(random_state=random_state))
#             en_params = dict(
#                 en__alpha=[alpha],
#                 en__l1_ratio=[l1_ratio],
#             )

#             tested_regressors = [(en, en_params)]

# rate different models
results_averaged_nonstatic = run_experiment(
    tested_regressors,
    regressor_params,
    pipeline_name,
    X_train,
    X_test,
    y_train,
    y_test,
    dataset_name,
    this_steps,
    results_averaged_nonstatic,
)
# Out:
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 21760 candidates, totalling 65280 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-ce31badde1d0> in <module>
#      34
#      35 # rate different models
# ---> 36 results_averaged_nonstatic = run_experiment(
#      37     tested_regressors,
#      38     regressor_params,
#
# <ipython-input-27-4ef969ec80df> in run_experiment(tested_regressors, regressor_params, pipeline_name, X_train, X_test, y_train, y_test, dataset_name, base_steps, results_df)
#      17         tested_params = {**regressor_params, **params}
#      18
# ---> 19         grid_result = rate_regressor(
#      20             X_train,
#      21             y_train,
#
# <ipython-input-26-181119cea49e> in rate_regressor(X_train, y_train, X_test, y_test, regressor, regressor_params, base_steps, cv)
#      17         verbose=1,
#      18     )
# ---> 19     grid_search.fit(X_train, y_train)
#      20
#      21     return grid_search
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/Programming/erpinator/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
results_averaged_nonstatic

# %%
this_steps = [(
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("ica_preprocessing", IcaPreprocessing()),
        ("spatial_filter", PCA(n_components=XXX, random_state=random_state))]

pre_processing_pipeline = Pipeline(steps=this_steps)

# perform pre-processing
pre_processed_pipeline = pre_processing_pipeline.fit(X_train)

# %%
pca_averaged_components = pre_processed_pipeline['spatial_filter'].components_

# %%
from numpy import save
save('pca_averaged_components.npy', data)

# %%
from numpy import load
# load array
pca_nonaveraged_components = load('../pca_components_static_non_averaged.npy')

# %% [markdown]
# ---

# %%
# for checking stability
def correlations(a0, a1):
    """Find correlation matrix between 2 matrices.
    It's similar to np.corrcoef, but it doesn't subtract the mean,
    when calculating the sum of squares.

    Parameters
    ----------
    a0, a1 : array_like
        2-D arrays containing multiple variables and observations.
        Each row represents a variable, and each column a single
        observation of all those variables.
        Their number of columns must be equal.
    """
    cov = a0 @ a1.T
    sum_of_squares0 = np.sum(a0 * a0, axis=1).reshape(-1, 1)
    sum_of_squares1 = np.sum(a1 * a1, axis=1).reshape(1, -1)
    return cov / (sum_of_squares0 @ sum_of_squares1) ** (1 / 2)


def factor_similarity(a0, a1):
    """Measure how similar are the factors.
    Reordering and rescaling them doesn't change the similarity.
    """
    corr = correlations(a0, a1)
    sim = abs(corr)  # don't care if factors' sign is flipped
    sim_hor = sim.max(axis=0)  # don't care if factors are reordered
    sim_ver = sim.max(axis=1)
    # in case some row or comuln have two candidates, choose the more pessimistic axis
    mean_sim = min(sim_hor.mean(), sim_ver.mean())
    # TODO? a more robust way would be to generate permutations and chack them
    return mean_sim

# %%
corr = correlations(pca_averaged_components, pca_nonaveraged_components)
corr

# %%
similarity = factor_similarity(pca_averaged_components, pca_nonaveraged_components)
similarity

# %%
for i in len(pca_nonaveraged):

# %% [markdown]
# ---

# %%
pipeline_name = "PCA_bins"
this_steps = ica_bins_steps()

# %%
for alpha in [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.2, 0.3, 0.4]:
    for l1_ratio in [
        0.0000001,
        0.000001,
        0.00001,
        0.0001,
        0.001,
        0.01,
        0.1,
        0.3,
        0.5,
        0.7,
        1,
    ]:

        en = ("en", ElasticNet(random_state=random_state))
        en_params = dict(
            en__alpha=[alpha],
            en__l1_ratio=[l1_ratio],
        )

        tested_regressors = [(en, en_params)]

        # rate different models
        res = run_experiment(
            tested_regressors,
            regressor_params,
            pipeline_name,
            X_train,
            X_test,
            y_train,
            y_test,
            dataset_name,
            this_steps,
            res,
        )

# %%
for alpha in [0.00001, 0.0001, 0.001, 0.01, 0.1, 0.2, 0.3, 0.4]:
    for gamma in [0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1, 1]:

        kr = ("kr", KernelRidge(kernel="rbf"))
        kr_params = dict(kr__alpha=[alpha], kr__gamma=[gamma])

        tested_regressors = [
            (kr, kr_params),
        ]

        # rate different models
        res = run_experiment(
            tested_regressors,
            regressor_params,
            pipeline_name,
            X_train,
            X_test,
            y_train,
            y_test,
            dataset_name,
            this_steps,
            res,
        )

# %%
for C in [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10]:
    for epsilon in [0.0001, 0.001, 0.01, 0.1, 1]:
        #         for gamma in [0.0000001, 0.000001, 0.00001, 0.0001, 0.001, 0.01, 0.1, 1]:

        svr = ("svr", SVR())
        svr_params = dict(
            svr__kernel=["linear"],
            svr__C=[C],
            svr__gamma=["scale"],
            svr__epsilon=[epsilon],
        )

        tested_regressors = [
            (svr, svr_params),
        ]

        # rate different models
        res = run_experiment(
            tested_regressors,
            regressor_params,
            pipeline_name,
            X_train,
            X_test,
            y_train,
            y_test,
            dataset_name,
            this_steps,
            res,
        )

# %% [markdown]
# ### Run Grid Search

# %%
results_df = pd.DataFrame()

# %%
en = ("en", ElasticNet(random_state=random_state))
en_params = dict(
    en__alpha=[0.3],
    en__l1_ratio=[1],
)

kr = ("kr", KernelRidge(kernel="rbf"))
kr_params = dict(kr__alpha=[0.4], kr__gamma=[0.00001])


svr = ("svr", SVR())
svr_params = dict(
    svr__kernel=["linear"],
    #     svr__C=[0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10],
    svr__C=[0.0001],
    svr__gamma=["scale"],
    #     svr__epsilon=[0.00001, 0.0001, 0.001, 0.01, 0.1, 1],
    svr__epsilon=[1],
)

tested_regressors = [(svr, svr_params), (kr, kr_params), (en, en_params)]

# %%
results_df = run_experiment(
    tested_regressors,
    regressor_params,
    pipeline_name,
    X_train,
    X_test,
    y_train,
    y_test,
    dataset_name,
    this_steps,
    results_df,
)

# %% [markdown]
# #### Save the data

# %%
results_df.to_pickle(
    "../../data/regression_PCA_15_all_4_bins_upto_8_features_" + dataset_name + ".pkl"
)

# %%
results_viz = results_df.drop(columns=["best_estimator"])
results_viz.to_pickle(
    "../../data/regression_PCA_15_all_4_bins_upto_8_features_visualization_"
    + dataset_name
    + ".pkl"
)

# %%
# with pd.option_context("display.max_rows", 2000):
#     display(res)
