# %% [markdown]
# # Rumination prediction

# %% [markdown]
# ### Imports

# %%
import os
import re
import glob
import os
import ast
import os.path as op
from collections import defaultdict
from copy import deepcopy

import pickle
from time import time
import pywt
import mne
import scipy
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import cesium.featurize
from plotly.subplots import make_subplots
from ipywidgets import Dropdown, FloatRangeSlider, IntSlider, FloatSlider, interact
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.base import TransformerMixin, BaseEstimator


import sys

# sys.path.append("..")
# from utils import *

# %% [markdown]
# ---
# ## Loading data
#
# Loading EEG data and data from rumination questionnaire. By default create_df_data loads all info from given file but one can specify it by passing a list of desired labels from csv file.

# %%
# paths TODO
dir_path = os.path.dirname(os.path.abspath(""))

# %%
tmin, tmax = -0.1, 0.6  # Start and end of the segments
signal_frequency = 256
ERROR = 0
CORRECT = 1
random_state = 0

# %%
channels_order_list = [
    "Fp1",
    "AF7",
    "AF3",
    "F1",
    "F3",
    "F5",
    "F7",
    "FT7",
    "FC5",
    "FC3",
    "FC1",
    "C1",
    "C3",
    "C5",
    "T7",
    "TP7",
    "CP5",
    "CP3",
    "CP1",
    "P1",
    "P3",
    "P5",
    "P7",
    "P9",
    "PO7",
    "PO3",
    "O1",
    "Iz",
    "Oz",
    "POz",
    "Pz",
    "CPz",
    "Fpz",
    "Fp2",
    "AF8",
    "AF4",
    "AFz",
    "Fz",
    "F2",
    "F4",
    "F6",
    "F8",
    "FT8",
    "FC6",
    "FC4",
    "FC2",
    "FCz",
    "Cz",
    "C2",
    "C4",
    "C6",
    "T8",
    "TP8",
    "CP6",
    "CP4",
    "CP2",
    "P2",
    "P4",
    "P6",
    "P8",
    "P10",
    "PO8",
    "PO4",
    "O2",
]

channels_dict = dict(zip(channels_order_list, np.arange(1, 64, 1)))

# %%
def create_df_data(
    test_participants=False,
    test_epochs=False,
    info_filename=None,
    info="all",
    personal=True,
):
    """Loads data for all participants and create DataFrame with optional additional info from given .csv file.

    On default, loads a train set: chooses only 80% of participants
    and for each of them chooses 80% of epochs.
    It will choose them deterministically.

    Participants with less than 10 epochs per condition are rejected.

    If test_participants is set to True, it will load remaining 20% of participants.
    If test_epochs is set to True, it will load remaining 20% of epochs.
    Test epochs are chronologically after train epochs,
    because it reflects real usage (first callibration and then classification).

    Parameters
    ----------
    test_participants: bool
        whether load data for training or final testing.
        If true load participants data for testing.
    test_epochs: bool
        whether load data for training or final testing.
        If true load epochs of each participants data for testing.
    info_filename: String | None
        path to .csv file with additional data.
    info: array
        listed parameters from the info file to be loaded.
        if 'all', load all parameters
    personal: bool
        whether a model will be both trained and tested on epochs from one person
        if false, person's epochs aren't split into test and train


    Returns
    -------
    go_nogo_data_df : pandas.DataFrame

    """
    print(os.path.abspath(""))
    dir_path = os.path.dirname(os.path.abspath(""))
    print(dir_path)
    header_files_glob = os.path.join(dir_path, "data/responses/*.vhdr")
    header_files = glob.glob(header_files_glob)

    header_files = sorted(header_files)
    go_nogo_data_df = pd.DataFrame()

    # cut 20% of data for testing
    h_train, h_test = train_test_split(header_files, test_size=0.2, random_state=0)

    if test_participants:
        header_files = h_test
    else:
        header_files = h_train

    for file in header_files:
        #  load eeg data for given participant
        participant_epochs = load_epochs_from_file(file)

        # and compute participant's id from file_name
        participant_id = re.match(r".*_(\w+).*", file).group(1)

        error = participant_epochs["error_response"]._data
        correct = participant_epochs["correct_response"]._data

        # exclude those participants who have too few samples
        if len(error) < 5 or len(correct) < 5:
            # not enough data for this participant
            continue

        if personal:
            # cut 20% of each participant's epochs for testing
            # shuffling is disabled to make sure test epochs are after train epochs
            # TODO: not sure if this step is necessary
            err_train, err_test = train_test_split(error, test_size=0.2, shuffle=False)
            cor_train, cor_test = train_test_split(
                correct, test_size=0.2, shuffle=False
            )
            if test_epochs:
                error = err_test
                correct = cor_test
            else:
                error = err_train
                correct = cor_train

        # construct dataframe for participant with: id|epoch_data|response_type|additional info...
        participant_df = create_df_from_epochs(
            participant_id, correct, error, info_filename, info
        )
        print(participant_id)
        go_nogo_data_df = go_nogo_data_df.append(participant_df, ignore_index=True)

    return go_nogo_data_df

# %%
def create_df_from_epochs(id, correct, error, info_filename, info):
    """Create df for each participant. DF structure is like: {id: String ; epoch: epoch_data ; marker: 1.0|0.0}
    1.0 means correct and 0.0 means error response.
    Default info extracted form .csv file is 'Rumination Full Scale' and participants' ids.
    With this info df structure is like:
    {id: String ; epoch: epoch_data ; marker: 1.0|0.0 ; File: id ; 'Rumination Full Scale': int}

    Parameters
    ----------
    id: String
        participant's id extracted from filename
    correct: array
        correct responses' data
    error: array
        error responses' data
    info_filename: String
        path to .csv file with additional data.
    info: array
        listed parameters from the info file to be loaded.
        if 'all', load all parameters

    Returns
    -------
    participant_df : pandas.DataFrame

    """
    participant_df = pd.DataFrame()
    info_df = pd.DataFrame()

    # get additional info from file
    if info_filename is not None:
        if info == "all":
            rumination_df = pd.read_csv(info_filename)
        else:
            rumination_df = pd.read_csv(info_filename, usecols=["File"] + info)
        info_df = (
            rumination_df.loc[rumination_df["File"] == id]
            .reset_index()
            .drop("index", axis=1)
        )

    for epoch in correct:
        epoch_df = pd.DataFrame(
            {"id": [id], "epoch": [epoch], "marker": [CORRECT]}
        ).join(info_df)
        participant_df = participant_df.append(epoch_df, ignore_index=True)

    for epoch in error:
        epoch_df = pd.DataFrame({"id": [id], "epoch": [epoch], "marker": [ERROR]}).join(
            info_df
        )
        participant_df = participant_df.append(epoch_df, ignore_index=True)

    return participant_df

# %%
def load_epochs_from_file(file, reject_bad_segments="auto", mask=None):
    """Load epochs from a header file.

    Args:
        file: path to a header file (.vhdr)
        reject_bad_segments: 'auto' means that bad segments are rejected automatically.

    Returns:
        mne Epochs

    """
    # Import the BrainVision data into an MNE Raw object
    raw = mne.io.read_raw_brainvision(file)

    # Construct annotation filename
    annot_file = file[:-4] + "vmrk"

    # Read in the event information as MNE annotations
    annotations = mne.read_annotations(annot_file)

    # Add the annotations to our raw object so we can use them with the data
    raw.set_annotations(annotations)

    # Map with response markers only
    event_dict = {
        "Stimulus/RE*ex*1_n*1_c_1*R*FB": 10004,
        "Stimulus/RE*ex*1_n*1_c_1*R*FG": 10005,
        "Stimulus/RE*ex*1_n*1_c_2*R": 10006,
        "Stimulus/RE*ex*1_n*2_c_1*R": 10007,
        "Stimulus/RE*ex*2_n*1_c_1*R": 10008,
        "Stimulus/RE*ex*2_n*2_c_1*R*FB": 10009,
        "Stimulus/RE*ex*2_n*2_c_1*R*FG": 10010,
        "Stimulus/RE*ex*2_n*2_c_2*R": 10011,
    }

    # Map for merged correct/error response markers
    merged_event_dict = {"correct_response": 0, "error_response": 1}

    # Reconstruct the original events from Raw object
    events, event_ids = mne.events_from_annotations(raw, event_id=event_dict)

    # Merge correct/error response events
    merged_events = mne.merge_events(
        events,
        [10004, 10005, 10009, 10010],
        merged_event_dict["correct_response"],
        replace_events=True,
    )
    merged_events = mne.merge_events(
        merged_events,
        [10006, 10007, 10008, 10011],
        merged_event_dict["error_response"],
        replace_events=True,
    )

    epochs = []
    bads = []
    this_reject_by_annotation = True

    # Read epochs
    epochs = mne.Epochs(
        raw=raw,
        events=merged_events,
        event_id=merged_event_dict,
        tmin=tmin,
        tmax=tmax,
        baseline=None,
        reject_by_annotation=this_reject_by_annotation,
        preload=True,
    )

    return epochs

# %% [markdown]
# #### Read the data

# %%
df_name = "go_nogo_df"
pickled_data_filename = "../data/" + df_name + ".pkl"
info_filename = "../data/Demographic_Questionnaires_Behavioral_Results_N=163.csv"

# Check if data is already loaded
if os.path.isfile(pickled_data_filename):
    print("Pickled file found. Loading pickled data...")
    epochs_df = pd.read_pickle(pickled_data_filename)
    print("Done")
else:
    print("Pickled file not found. Loading data...")
    epochs_df = create_df_data(
        test_participants=False, info="all", personal=False, info_filename=info_filename
    )
    epochs_df.name = df_name
    # save loaded data into a pickle file
    epochs_df.to_pickle("../data/" + epochs_df.name + ".pkl")
    print("Done. Pickle file created")
# Out:
# Pickled file not found. Loading data...
# /Users/anuszka/Programming/rumination_project/erpinator/notebooks
# /Users/anuszka/Programming/rumination_project/erpinator
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AR0607-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AR0607-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 50 bad epochs dropped
# AR0607
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_HN2708-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_HN2708-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 264 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 264 events and 181 original time points ...
# 49 bad epochs dropped
# HN2708
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MK1007-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MK1007-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 271 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 271 events and 181 original time points ...
# 46 bad epochs dropped
# MK1007
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AO2010-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AO2010-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# <ipython-input-25-4f2834128383>:13: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_brainvision(file)
# <ipython-input-25-4f2834128383>:22: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw.set_annotations(annotations)
# 103 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JL2111-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JL2111-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 277 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 277 events and 181 original time points ...
# 185 bad epochs dropped
# JL2111
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MZ0502-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MZ0502-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 233 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 233 events and 181 original time points ...
# 211 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AK2308-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AK2308-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 235 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 235 events and 181 original time points ...
# 109 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IG0308-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IG0308-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 23 bad epochs dropped
# IG0308
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MB1610-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MB1610-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 38 bad epochs dropped
# MB1610
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_BZ1004-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_BZ1004-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 262 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 262 events and 181 original time points ...
# 143 bad epochs dropped
# BZ1004
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AP0706-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AP0706-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 227 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 227 events and 181 original time points ...
# 131 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MD2903-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MD2903-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 248 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 248 events and 181 original time points ...
# 33 bad epochs dropped
# MD2903
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_PS1511-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_PS1511-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 233 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 233 events and 181 original time points ...
# 19 bad epochs dropped
# PS1511
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MW1710-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MW1710-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 39 bad epochs dropped
# MW1710
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_RS0303-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_RS0303-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 252 events and 181 original time points ...
# 35 bad epochs dropped
# RS0303
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MB2105-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MB2105-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 196 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AS0401-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AS0401-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 230 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 230 events and 181 original time points ...
# 24 bad epochs dropped
# AS0401
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MK1711-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MK1711-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 269 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 269 events and 181 original time points ...
# 116 bad epochs dropped
# MK1711
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KM0312-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KM0312-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 87 bad epochs dropped
# KM0312
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IS0103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IS0103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 253 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 253 events and 181 original time points ...
# 29 bad epochs dropped
# IS0103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MB0503-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MB0503-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 257 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 257 events and 181 original time points ...
# 107 bad epochs dropped
# MB0503
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AN2907-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AN2907-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 275 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 275 events and 181 original time points ...
# 44 bad epochs dropped
# AN2907
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS2404-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS2404-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 252 events and 181 original time points ...
# 63 bad epochs dropped
# KS2404
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AS2008-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AS2008-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 86 bad epochs dropped
# AS2008
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_PW2803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_PW2803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 245 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 245 events and 181 original time points ...
# 94 bad epochs dropped
# PW2803
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JP1201-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JP1201-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 312 events and 181 original time points ...
# 184 bad epochs dropped
# JP1201
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MC1506-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MC1506-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 22 bad epochs dropped
# MC1506
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AB0612-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AB0612-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 262 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 262 events and 181 original time points ...
# 12 bad epochs dropped
# AB0612
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IB1704-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IB1704-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 218 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 218 events and 181 original time points ...
# 66 bad epochs dropped
# IB1704
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS2803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS2803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 84 bad epochs dropped
# KS2803
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KK1110-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KK1110-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 243 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 243 events and 181 original time points ...
# 6 bad epochs dropped
# KK1110
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DJ0205-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DJ0205-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 181 original time points ...
# 204 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AI2201-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AI2201-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 222 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 222 events and 181 original time points ...
# 211 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JZ0904-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JZ0904-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 245 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 245 events and 181 original time points ...
# 187 bad epochs dropped
# JZ0904
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_VZ0501-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_VZ0501-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 239 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 239 events and 181 original time points ...
# 103 bad epochs dropped
# VZ0501
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS3101-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS3101-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 271 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 271 events and 181 original time points ...
# 87 bad epochs dropped
# KS3101
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MP0407-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MP0407-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 247 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 247 events and 181 original time points ...
# 64 bad epochs dropped
# MP0407
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_RJ1803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_RJ1803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 237 events and 181 original time points ...
# 34 bad epochs dropped
# RJ1803
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MW1508-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MW1508-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 181 original time points ...
# 37 bad epochs dropped
# MW1508
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_NB1103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_NB1103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 239 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 239 events and 181 original time points ...
# 67 bad epochs dropped
# NB1103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DP2901-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DP2901-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 241 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 241 events and 181 original time points ...
# 55 bad epochs dropped
# DP2901
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MD1502-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MD1502-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 255 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 255 events and 181 original time points ...
# 187 bad epochs dropped
# MD1502
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KK0110-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KK0110-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 249 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 249 events and 181 original time points ...
# 46 bad epochs dropped
# KK0110
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JG0702-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JG0702-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 60 bad epochs dropped
# JG0702
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MC1404-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MC1404-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 229 events and 181 original time points ...
# 43 bad epochs dropped
# MC1404
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MC1606-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MC1606-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 263 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 263 events and 181 original time points ...
# 69 bad epochs dropped
# MC1606
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JM2103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JM2103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 253 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 253 events and 181 original time points ...
# 225 bad epochs dropped
# JM2103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DP2803-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DP2803-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 229 events and 181 original time points ...
# 228 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DP1905-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DP1905-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 244 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 244 events and 181 original time points ...
# 4 bad epochs dropped
# DP1905
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AK1312-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AK1312-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 260 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 260 events and 181 original time points ...
# 221 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MK1506-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MK1506-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 132 bad epochs dropped
# MK1506
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AP2105-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AP2105-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 123 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MM1112-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MM1112-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 235 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 235 events and 181 original time points ...
# 13 bad epochs dropped
# MM1112
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AO2601-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AO2601-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# <ipython-input-25-4f2834128383>:13: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_brainvision(file)
# <ipython-input-25-4f2834128383>:22: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw.set_annotations(annotations)
# 146 bad epochs dropped
# AO2601
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AK2012-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AK2012-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 262 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 262 events and 181 original time points ...
# 167 bad epochs dropped
# AK2012
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KD1102-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KD1102-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 224 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 224 events and 181 original time points ...
# 71 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_FK0508-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_FK0508-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 240 events and 181 original time points ...
# 44 bad epochs dropped
# FK0508
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KB0101-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KB0101-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 265 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 265 events and 181 original time points ...
# 72 bad epochs dropped
# KB0101
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AC2011-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AC2011-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 67 bad epochs dropped
# AC2011
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_ZW2709-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_ZW2709-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 225 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 225 events and 181 original time points ...
# 53 bad epochs dropped
# ZW2709
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS2308-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KS2308-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 238 events and 181 original time points ...
# 79 bad epochs dropped
# KS2308
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AD2906-64 el.vhdr...
# Setting channel info structure...
# ...
# Loading data for 288 events and 181 original time points ...
# 179 bad epochs dropped
# MG2806
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_WC0301-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_WC0301-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 294 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 294 events and 181 original time points ...
# 258 bad epochs dropped
# WC0301
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JS0303-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JS0303-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 250 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 250 events and 181 original time points ...
# 166 bad epochs dropped
# JS0303
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KB2309-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KB2309-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 248 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 248 events and 181 original time points ...
# 103 bad epochs dropped
# KB2309
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AR1506-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AR1506-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 258 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 258 events and 181 original time points ...
# 100 bad epochs dropped
# AR1506
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KJ1811-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KJ1811-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 236 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 236 events and 181 original time points ...
# 76 bad epochs dropped
# KJ1811
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_TT2311-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_TT2311-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 268 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 268 events and 181 original time points ...
# 191 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_TZ2302-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_TZ2302-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 247 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 247 events and 181 original time points ...
# <ipython-input-25-4f2834128383>:13: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_brainvision(file)
# <ipython-input-25-4f2834128383>:22: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw.set_annotations(annotations)
# 72 bad epochs dropped
# TZ2302
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_BW1003-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_BW1003-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 251 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 251 events and 181 original time points ...
# 21 bad epochs dropped
# BW1003
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IA2105-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_IA2105-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 241 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 241 events and 181 original time points ...
# 29 bad epochs dropped
# IA2105
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_PD0809-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_PD0809-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 264 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 264 events and 181 original time points ...
# 38 bad epochs dropped
# PD0809
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KN1606-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KN1606-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 247 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 247 events and 181 original time points ...
# 131 bad epochs dropped
# KN1606
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JM3011-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JM3011-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 283 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 283 events and 181 original time points ...
# 94 bad epochs dropped
# JM3011
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KM2404-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_KM2404-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 81 bad epochs dropped
# KM2404
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_BB1406-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_BB1406-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 239 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 239 events and 181 original time points ...
# 125 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AP0601-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AP0601-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 246 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 246 events and 181 original time points ...
# 133 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AG1511-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_AG1511-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 229 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 229 events and 181 original time points ...
# 83 bad epochs dropped
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MA0706-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MA0706-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 260 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 260 events and 181 original time points ...
# 32 bad epochs dropped
# MA0706
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JM0103-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_JM0103-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG']
# Not setting metadata
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 252 events and 181 original time points ...
# 47 bad epochs dropped
# JM0103
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MJ1306-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_MJ1306-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 254 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 254 events and 181 original time points ...
# 66 bad epochs dropped
# MJ1306
# Extracting parameters from /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DO0607-64 el.vhdr...
# Setting channel info structure...
# Finding 'sfreq' from header file: /Users/anuszka/Programming/rumination_project/erpinator/data/responses/GNG_DO0607-64 el.vhdr
# Used Annotations descriptions: ['Stimulus/RE*ex*1_n*1_c_1*R*FB', 'Stimulus/RE*ex*1_n*1_c_1*R*FG', 'Stimulus/RE*ex*1_n*1_c_2*R', 'Stimulus/RE*ex*1_n*2_c_1*R', 'Stimulus/RE*ex*2_n*1_c_1*R', 'Stimulus/RE*ex*2_n*2_c_1*R*FB', 'Stimulus/RE*ex*2_n*2_c_1*R*FG', 'Stimulus/RE*ex*2_n*2_c_2*R']
# Not setting metadata
# Not setting metadata
# 242 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 242 events and 181 original time points ...
# 27 bad epochs dropped
# DO0607
# Done. Pickle file created

# %% [markdown]
# #### Rearrange data:  from: *one row - one epoch* to *one row - one participant*
#
# epochs column contain list of epochs from given condition (marker = error or correct)

# %%
epochs_df
# Out:
#            id                                              epoch  marker  \
# 0      AR0607  [[-4.607e-06, 1.95e-06, 1.0529999999999999e-05...       1
# 1      AR0607  [[8.2e-08, -6.307e-06, -6.5709999999999994e-06...       1
# 2      AR0607  [[8.9e-07, 3.8999999999999997e-07, -2.45e-07, ...       1
# 3      AR0607  [[-6.958e-06, -3.568e-06, 6.4e-07, 1.074e-06, ...       1
# 4      AR0607  [[-4.1029999999999995e-06, -4.769999999999999e...       1
# ...       ...                                                ...     ...
# 18540  DO0607  [[-2.6309999999999995e-06, -2.278e-06, 3.70299...       0
# 18541  DO0607  [[-2.805e-06, -4.706e-06, 8.38e-07, 1.00099999...       0
# 18542  DO0607  [[-9.005000000000001e-06, -1.1927e-05, -9.9039...       0
# 18543  DO0607  [[-1.1813999999999999e-05, -1.2176e-05, -1.205...       0
# 18544  DO0607  [[-3.847999999999999e-06, 6.14e-07, 3.53999999...       0
#
#          File  Sex  Handedness  Age  DASS-21 Stress scale  \
# 0      AR0607    0           1   22                  1.14
# 1      AR0607    0           1   22                  1.14
# 2      AR0607    0           1   22                  1.14
# 3      AR0607    0           1   22                  1.14
# 4      AR0607    0           1   22                  1.14
# ...       ...  ...         ...  ...                   ...
# 18540  DO0607    1           1   30                  2.00
# 18541  DO0607    1           1   30                  2.00
# 18542  DO0607    1           1   30                  2.00
# 18543  DO0607    1           1   30                  2.00
# 18544  DO0607    1           1   30                  2.00
#
#        DASS-21 Depression scale  DASS-21 Anxiety scale  ...  Number Error  \
# 0                          1.57                   1.14  ...            17
# 1                          1.57                   1.14  ...            17
# 2                          1.57                   1.14  ...            17
# 3                          1.57                   1.14  ...            17
# 4                          1.57                   1.14  ...            17
# ...                         ...                    ...  ...           ...
# 18540                      1.57                   2.00  ...            20
# 18541                      1.57                   2.00  ...            20
# 18542                      1.57                   2.00  ...            20
# 18543                      1.57                   2.00  ...            20
# 18544                      1.57                   2.00  ...            20
#
#        Number Inhibited Response  Trials sum  mean Post-Hit RT  \
# 0                             95         336           0.38784
# 1                             95         336           0.38784
# 2                             95         336           0.38784
# 3                             95         336           0.38784
# 4                             95         336           0.38784
# ...                          ...         ...               ...
# 18540                         92         336           0.29637
# 18541                         92         336           0.29637
# 18542                         92         336           0.29637
# 18543                         92         336           0.29637
# 18544                         92         336           0.29637
#
#        mean Post-Fast-Hit RT  mean Post-Slow-Hit RT  mean Post-Error RT  \
# 0                   0.403654               0.370218            0.471611
# 1                   0.403654               0.370218            0.471611
# 2                   0.403654               0.370218            0.471611
# 3                   0.403654               0.370218            0.471611
# 4                   0.403654               0.370218            0.471611
# ...                      ...                    ...                 ...
# 18540               0.303883               0.287442            0.347652
# 18541               0.303883               0.287442            0.347652
# 18542               0.303883               0.287442            0.347652
# 18543               0.303883               0.287442            0.347652
# 18544               0.303883               0.287442            0.347652
#
#        mean post-Inhibited Response  \
# 0                          0.424927
# 1                          0.424927
# 2                          0.424927
# 3                          0.424927
# 4                          0.424927
# ...                             ...
# 18540                      0.308988
# 18541                      0.308988
# 18542                      0.308988
# 18543                      0.308988
# 18544                      0.308988
#
#        mean Post-Error RT minus mean Post-Hit RT  \
# 0                                       0.083771
# 1                                       0.083771
# 2                                       0.083771
# 3                                       0.083771
# 4                                       0.083771
# ...                                          ...
# 18540                                   0.051281
# 18541                                   0.051281
# 18542                                   0.051281
# 18543                                   0.051281
# 18544                                   0.051281
#
#        mean Post-Error RT minus mean Post-Inhibited Response
# 0                                               0.046683
# 1                                               0.046683
# 2                                               0.046683
# 3                                               0.046683
# 4                                               0.046683
# ...                                                  ...
# 18540                                           0.038664
# 18541                                           0.038664
# 18542                                           0.038664
# 18543                                           0.038664
# 18544                                           0.038664
#
# [18545 rows x 32 columns]

# %%
data_df = (
    epochs_df.groupby(
        ["id", "marker"],
        sort=False,
    )
    .apply(
        lambda group_df: pd.Series(
            {
                "epochs": np.array(group_df["epoch"].to_list(), dtype="float64"),
                "Rumination Full Scale": np.mean(group_df["Rumination Full Scale"]),
                "Anxiety": np.mean(group_df["DASS-21 Anxiety scale"]),
                "Stress": np.mean(group_df["DASS-21 Stress scale"]),
                "Depression": np.mean(group_df["DASS-21 Depression scale"]),
            }
        )
    )
    .reset_index()
)

# %%
summary_df = (
    epochs_df.groupby(
        ["id", "marker"],
        sort=False,
    )
    .size()
    .reset_index(name="counts")
)

participants_data_len = np.array(
    summary_df[summary_df["marker"] == 0]["counts"].tolist()
)

# %%
# participant data indices for identifying participants data after spatial filtering

participants_data_indices = []
index = 0

for participant_len in participants_data_len:
    participant_indices = (index, index + participant_len - 1)
    participants_data_indices.append(participant_indices)
    index = index + participant_len

participants_data_indices = np.array(participants_data_indices)

# %% [markdown]
# ---
# ## Training and prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import permutation_test_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from tempfile import mkdtemp
from sklearn.linear_model import Ridge
from sklearn.kernel_ridge import KernelRidge


from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# #### Create X train and y train sets

# %%
# selection of the analysed condition: erroneous responses or correct responses
dataset = ERROR
dataset_name = "correct" if dataset == CORRECT else "error"

# %%
# shape 4-D: participant x epoch x channel x timepoints
X_train = np.array(data_df[data_df["marker"] == dataset]["epochs"].tolist())

# shape 1-D: rumination score
rumination = np.array(
    data_df[data_df["marker"] == dataset]["Rumination Full Scale"].to_list()
)

anxiety = np.array(data_df[data_df["marker"] == dataset]["Anxiety"].to_list())
stress = np.array(data_df[data_df["marker"] == dataset]["Stress"].to_list())
depression = np.array(data_df[data_df["marker"] == dataset]["Depression"].to_list())

# y_train = np.stack((rumination, depresion), axis=1)
y_train = rumination

# X_train = np.array(epochs_df[epochs_df["marker"] == dataset]["epoch"].tolist())

# # shape 1-D: rumination score
# y_train = np.array(
#     epochs_df[epochs_df["marker"] == dataset]["Rumination Full Scale"].to_list()
# )

# %%
X_test = []
y_test = []

# %%
X_train.shape
# Out:
# (108,)

# %% [markdown]
# ----

# %%
rum_depr_corr = np.corrcoef(rumination, depression)
rum_depr_corr
# Out:
# array([[1.        , 0.47601841],
#        [0.47601841, 1.        ]])

# %%
rum_anx_corr = np.corrcoef(rumination, anxiety)
rum_anx_corr
# Out:
# array([[1.       , 0.2259998],
#        [0.2259998, 1.       ]])

# %%
rum_stress_corr = np.corrcoef(rumination, stress)
rum_stress_corr
# Out:
# array([[1.        , 0.48562839],
#        [0.48562839, 1.        ]])

# %% [markdown]
# ---
# ### Experiments
#
# Parameters of experiments:
# - regressors
# - hyperparameters
# - preprocessing pipelines

# %% [markdown]
# #### Prepare experiment estimating
# ____

# %%
# Rating model with grid search


def rate_regressor(
    X_train, y_train, X_test, y_test, regressor, regressor_params, base_steps, cv=3
):
    # define cross-validation method
    cv_kf = KFold(n_splits=3)

    pipeline = Pipeline(steps=base_steps + [regressor])
    param_grid = regressor_params
    grid_search = GridSearchCV(
        pipeline,
        param_grid,
        cv=cv_kf,
        scoring={"r2", "neg_mean_absolute_error", "neg_mean_squared_error"},
        refit="r2",
        return_train_score=True,
        n_jobs=4,
        verbose=1,
        error_score="raise",
    )
    grid_search.fit(X_train, y_train)

    return grid_search

# %%
# conducting experiment and saving selected info do result df


def run_experiment(
    tested_regressors,
    regressor_params,
    pipeline_name,
    X_train,
    X_test,
    y_train,
    y_test,
    dataset_name,
    base_steps,
    results_df,
):

    for (regressor, params) in tested_regressors:
        print(f"Rating {regressor} \n")
        tested_params = {**regressor_params, **params}

        # enter to grid search
        grid_result = rate_regressor(
            X_train,
            y_train,
            X_test,
            y_test,
            regressor,
            tested_params,
            base_steps,
            cv=3,
        )

        #     predictions = grid_result.predict(X_test)
        #     r2 = grid_result.score(X_test, y_test)
        #     mae = mean_absolute_error(y_test, predictions)
        #     r2_adj = r2_adjusted_scorer(y_test, predictions, len(X_test[0]), len(X_test))

        best_estimator_index = grid_result.best_index_
        mean_cv_r2 = grid_result.cv_results_["mean_test_r2"][best_estimator_index]
        std_cv_r2 = grid_result.cv_results_["std_test_r2"][best_estimator_index]
        mean_cv_neg_mean_absolute_error = grid_result.cv_results_[
            "mean_test_neg_mean_absolute_error"
        ][best_estimator_index]
        std_cv_neg_mean_absolute_error = grid_result.cv_results_[
            "std_test_neg_mean_absolute_error"
        ][best_estimator_index]
        mean_cv_neg_mean_squared_error = grid_result.cv_results_[
            "mean_test_neg_mean_squared_error"
        ][best_estimator_index]
        std_cv_neg_mean_squared_error = grid_result.cv_results_[
            "std_test_neg_mean_squared_error"
        ][best_estimator_index]
        
        mean_train_r2 = grid_result.cv_results_["mean_train_r2"][best_estimator_index]
        mean_train_mae = grid_result.cv_results_["mean_train_neg_mean_absolute_error"][best_estimator_index]
        mean_train_mse = grid_result.cv_results_["mean_train_neg_mean_squared_error"][best_estimator_index]


        print(f"     Best parameters: {grid_result.best_params_}")
        print(f"     mean r2: {mean_cv_r2}           ± {round(std_cv_r2,3)}")
        print(f"     mean r2 train: {mean_train_r2}")

        cv_results = grid_result.cv_results_

        # calculate p-value
        scores_, pvalue_ = calculate_p_permutations(
            grid_result.best_estimator_, X_train, y_train
        )

        # insert selected info to df
        data = {
            "data_set": dataset_name,
            "pipeline_name": pipeline_name,
            "model": regressor[0],
            "parameters": grid_result.best_params_,
            "mean_cv_r2": mean_cv_r2,
            "std_cv_r2": std_cv_r2,
            "mean_cv_mae": mean_cv_neg_mean_absolute_error,
            "std_cv_mae": std_cv_neg_mean_absolute_error,
            "mean_cv_mse":mean_cv_neg_mean_squared_error,
            "std_cv_mse": std_cv_neg_mean_squared_error,
            "cv_results": cv_results,
            "mean_train_r2": mean_train_r2,
            "mean_train_mae":mean_train_mae,
            "mean_train_mse":mean_train_mse,
            "p-value": pvalue_,
            "best_estimator": grid_result.best_estimator_,
        }

        results_df = results_df.append(data, ignore_index=True)
    return results_df

# %%
# Calculating p-value with permutation test


def calculate_p_permutations(estimator, X, y, cv=3, n_permutations=100, n_jobs=10):

    score_, perm_scores_, pvalue_ = permutation_test_score(
        estimator, X, y, cv=cv, n_permutations=n_permutations, n_jobs=n_jobs
    )

    # summarize
    print(f"     The permutation P-value is = {pvalue_:.3f}")
    print(f"     The permutation score is = {score_:.3f}\n")

    return score_, pvalue_

# %% [markdown]
# #### Define pipelines
# ___

# %%
from rumination_experiment_transformers import *

from sklearn.decomposition import FastICA
from sklearn.decomposition import PCA

timepoints_count = 181

# %%
# SPATIAL FILTER - BINS


def spatial_filter_bins_steps(spatial_filter_n_components):

    steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("spatial_filter_preprocessing", SpatialFilterPreprocessing()),
        (
            "spatial_filter",
            PCA(n_components=spatial_filter_n_components, random_state=random_state),
        ),
        (
            "spatial_filter_postprocessing",
            SpatialFilterPostprocessing(
                timepoints_count=timepoints_count,
                participants_data_indices=participants_data_indices,
            ),
        ),
        ("lowpass_filter", LowpassFilter()),
        (
            "average_epochs",
            AveragePerParticipant(),
        ),
        ("binning", BinTransformer(step=step_tp)),
        ("data_channel_swap", ChannelDataSwap()),
        ("postprocessing", PostprocessingTransformer()),
        ("scaler", StandardScaler()),
        # ("feature_selection", PCA(n_components=2, random_state=random_state)),
    ]

    return steps

# %%
# BINS
def erp_bins_steps():
    steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("lowpass_filter", LowpassFilter()),
        (
            "average_epochs",
            AveragePerParticipant(),
        ),
        ("binning", BinTransformer(step=step_tp)),
        ("data_channel_swap", ChannelDataSwap()),
        ("postprocessing", PostprocessingTransformer()),
        ("scaler", StandardScaler()),
        # ("feature_selection", PCA(random_state=random_state)),
    ]

    return steps

# %% [markdown]
# Generate estimator HTML representation

# %%
# from sklearn.utils import estimator_html_repr

# with open("my_estimator.html", "w") as f:
#     f.write(estimator_html_repr(Pipeline(this_steps)))

# %% [markdown]
# ### Perform Experiments
# ___

# %% [markdown]
# #### Global parameters common for each experiment

# %%
# channels that will be included in the experiment

red_box = [
    "F1",
    "Fz",
    "F2",
    "FC1",
    "FCz",
    "FC2",
    "C1",
    "Cz",
    "C2",
    "CP1",
    "CPz",
    "CP2",
    "P1",
    "Pz",
    "P2",
]
significant_channels = [channels_dict[channel] for channel in red_box]

# %%
# spatial filters

spatial_filters_dict = {
    "ICA": FastICA(random_state=random_state),
    "PCA": PCA(random_state=random_state),
}

# %%
# bins width

step_in_ms = 50  # in miliseconds (?)
step_tp = int(signal_frequency * step_in_ms / 1000)  # in timepoints

# %% [markdown]
# ---
# #### Experiment 1
#
# - spatial filter
# - bins
# - feature selection

# %% [markdown]
# ##### Spatial filter & binning

# %%
# define hyperparameters of pipeline

spatial_filter = "PCA"

min_spatial_filter = 1
max_spatial_filter = 9
step_spatial_filter = 1

min_feature_selection = 1
max_feature_selection = 9
step_feature_selection = 1


regressor_params = dict(
    # spatial_filter__n_components=np.arange(
    #     min_spatial_filter, max_spatial_filter, step_spatial_filter
    # ),
    feature_selection__n_components=np.arange(
        min_feature_selection, max_feature_selection, step_feature_selection
    ),
)

regressor_steps = [("feature_selection", PCA(random_state=random_state))]

# %%
# define estimators and their hyperparameters

en = ("en", ElasticNet(random_state=random_state))
en_params = dict(
    # en__alpha=np.logspace(-7, 3, num=20, base=10), en__l1_ratio=np.logspace(-8, 0, num=20,base=10)
    en__alpha=np.logspace(-7, 3, num=20, base=10),
    en__l1_ratio=np.logspace(-8, 0, num=17, base=10),
)

kr = ("kr", KernelRidge(kernel="rbf"))
kr_params = dict(
    kr__alpha=np.logspace(-5, 3, num=20, base=10),
    kr__gamma=np.logspace(-5, 3, num=20, base=10),
)


svr = ("svr", SVR())
svr_params = dict(
    svr__kernel=["linear", "rbf"],
    svr__C=[0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10],
    svr__gamma=["scale"],
    svr__epsilon=[0.00001, 0.0001, 0.001, 0.01, 0.1, 1],
)

tested_regressors = [
    # (svr, svr_params), 
    # (kr, kr_params), 
    (en, en_params)
]

# %% [markdown]
# #### Run Experiment

# %%
from warnings import filterwarnings

filterwarnings("ignore")

# %%
results_static_df = pd.DataFrame()

# %%
# manually test different numbers of spatial filter components

for n_components in range(min_spatial_filter, max_spatial_filter, step_spatial_filter):

    pipeline_name = f"{spatial_filter}_{n_components}_bins"

    this_steps = spatial_filter_bins_steps(spatial_filter_n_components=n_components)
    pre_processing_pipeline = Pipeline(steps=this_steps)

    # perform pre-processing
    pre_processed_X = pre_processing_pipeline.fit_transform(X_train)
    
    # rate different models
    results_static_df = run_experiment(
        tested_regressors,
        regressor_params,
        pipeline_name,
        pre_processed_X,
        X_test,
        y_train,
        y_test,
        dataset_name,
        regressor_steps,
        results_static_df,
    )
# Out:
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 1, 181)
# float64
# IN BINS RETURN SHAPE: (108, 1, 14)
# SWAP shape: (1, 108, 14)
# POST SHAPE:(108, 14)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 0.6951927961775606, 'en__l1_ratio': 1e-08, 'feature_selection__n_components': 8}
#      mean r2: 0.018827187074034857           ± 0.01
#      mean r2 train: 0.09349037993319775
#      The permutation P-value is = 0.050
#      The permutation score is = 0.019
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 2, 181)
# float64
# IN BINS RETURN SHAPE: (108, 2, 14)
# SWAP shape: (2, 108, 14)
# POST SHAPE:(108, 28)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 0.20691380811147903, 'en__l1_ratio': 0.03162277660168379, 'feature_selection__n_components': 6}
#      mean r2: 0.09355424457473245           ± 0.056
#      mean r2 train: 0.1320573501072049
#      The permutation P-value is = 0.020
#      The permutation score is = 0.094
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 3, 181)
# float64
# IN BINS RETURN SHAPE: (108, 3, 14)
# SWAP shape: (3, 108, 14)
# POST SHAPE:(108, 42)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 0.001623776739188721, 'en__l1_ratio': 1.0, 'feature_selection__n_components': 8}
#      mean r2: 0.15357771944772602           ± 0.109
#      mean r2 train: 0.19285986886215636
#      The permutation P-value is = 0.010
#      The permutation score is = 0.154
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 4, 181)
# float64
# IN BINS RETURN SHAPE: (108, 4, 14)
# SWAP shape: (4, 108, 14)
# POST SHAPE:(108, 56)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 0.01832980710832434, 'en__l1_ratio': 1.0, 'feature_selection__n_components': 8}
#      mean r2: 0.13324981282483028           ± 0.103
#      mean r2 train: 0.19750164750689128
#      The permutation P-value is = 0.010
#      The permutation score is = 0.133
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 5, 181)
# float64
# IN BINS RETURN SHAPE: (108, 5, 14)
# SWAP shape: (5, 108, 14)
# POST SHAPE:(108, 70)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 1e-07, 'en__l1_ratio': 1e-08, 'feature_selection__n_components': 8}
#      mean r2: 0.1459259864976954           ± 0.058
#      mean r2 train: 0.19967045913146134
#      The permutation P-value is = 0.010
#      The permutation score is = 0.146
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 6, 181)
# float64
# IN BINS RETURN SHAPE: (108, 6, 14)
# SWAP shape: (6, 108, 14)
# POST SHAPE:(108, 84)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 0.061584821106602544, 'en__l1_ratio': 0.1, 'feature_selection__n_components': 8}
#      mean r2: 0.09280823924078836           ± 0.037
#      mean r2 train: 0.1750988501307691
#      The permutation P-value is = 0.010
#      The permutation score is = 0.093
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 7, 181)
# float64
# IN BINS RETURN SHAPE: (108, 7, 14)
# SWAP shape: (7, 108, 14)
# POST SHAPE:(108, 98)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 2.3357214690901213, 'en__l1_ratio': 1e-08, 'feature_selection__n_components': 8}
#      mean r2: 0.06311102545896552           ± 0.055
#      mean r2 train: 0.1490627307093643
#      The permutation P-value is = 0.020
#      The permutation score is = 0.063
#
# EXTRACTION (108,)
# IN LOWPASS FILTER
# IN BUTTERWORTH FILTER SHAPE: (108,)
# IN AVERAGE X SHAPE: (108,)
# IN AVERAGE RETURN SHAPE: (108, 8, 181)
# float64
# IN BINS RETURN SHAPE: (108, 8, 14)
# SWAP shape: (8, 108, 14)
# POST SHAPE:(108, 112)
# Rating ('en', ElasticNet(random_state=0))
#
# Fitting 3 folds for each of 2720 candidates, totalling 8160 fits
#      Best parameters: {'en__alpha': 2.3357214690901213, 'en__l1_ratio': 1e-08, 'feature_selection__n_components': 7}
#      mean r2: 0.024822405656234465           ± 0.075
#      mean r2 train: 0.12741149891635054
#      The permutation P-value is = 0.020
#      The permutation score is = 0.025

# %%
results_static_df
# Out:
#                                       best_estimator  \
# 0  (PCA(n_components=8, random_state=0), ElasticN...
# 1  (PCA(n_components=6, random_state=0), ElasticN...
# 2  (PCA(n_components=8, random_state=0), ElasticN...
# 3  (PCA(n_components=8, random_state=0), ElasticN...
# 4  (PCA(n_components=8, random_state=0), ElasticN...
# 5  (PCA(n_components=8, random_state=0), ElasticN...
# 6  (PCA(n_components=8, random_state=0), ElasticN...
# 7  (PCA(n_components=7, random_state=0), ElasticN...
#
#                                           cv_results data_set  mean_cv_mae  \
# 0  {'mean_fit_time': [0.012073119481404623, 0.017...    error    -0.741456
# 1  {'mean_fit_time': [0.0053738753000895185, 0.03...    error    -0.702020
# 2  {'mean_fit_time': [0.0034896532694498696, 0.00...    error    -0.673311
# 3  {'mean_fit_time': [0.0048177242279052734, 0.00...    error    -0.676074
# 4  {'mean_fit_time': [0.00538333257039388, 0.0055...    error    -0.671556
# 5  {'mean_fit_time': [0.00560768445332845, 0.0073...    error    -0.701762
# 6  {'mean_fit_time': [0.007640997568766276, 0.006...    error    -0.710471
# 7  {'mean_fit_time': [0.004378318786621094, 0.008...    error    -0.726400
#
#    mean_cv_mse  mean_cv_r2  mean_train_mae  mean_train_mse  mean_train_r2  \
# 0    -0.813407    0.018827       -0.722335       -0.753777       0.093490
# 1    -0.756170    0.093554       -0.691843       -0.724680       0.132057
# 2    -0.713155    0.153578       -0.666541       -0.674823       0.192860
# 3    -0.727698    0.133250       -0.654202       -0.670471       0.197502
# 4    -0.713920    0.145926       -0.645155       -0.670519       0.199670
# 5    -0.757027    0.092808       -0.658928       -0.689756       0.175099
# 6    -0.783725    0.063111       -0.676820       -0.710431       0.149063
# 7    -0.817485    0.024822       -0.689649       -0.728090       0.127411
#
#   model   p-value                                         parameters  \
# 0    en  0.049505  {'en__alpha': 0.6951927961775606, 'en__l1_rati...
# 1    en  0.019802  {'en__alpha': 0.20691380811147903, 'en__l1_rat...
# 2    en  0.009901  {'en__alpha': 0.001623776739188721, 'en__l1_ra...
# 3    en  0.009901  {'en__alpha': 0.01832980710832434, 'en__l1_rat...
# 4    en  0.009901  {'en__alpha': 1e-07, 'en__l1_ratio': 1e-08, 'f...
# 5    en  0.009901  {'en__alpha': 0.061584821106602544, 'en__l1_ra...
# 6    en  0.019802  {'en__alpha': 2.3357214690901213, 'en__l1_rati...
# 7    en  0.019802  {'en__alpha': 2.3357214690901213, 'en__l1_rati...
#
#   pipeline_name  std_cv_mae  std_cv_mse  std_cv_r2
# 0    PCA_1_bins    0.044699    0.104915   0.009597
# 1    PCA_2_bins    0.060528    0.135069   0.055825
# 2    PCA_3_bins    0.080347    0.174890   0.108653
# 3    PCA_4_bins    0.078295    0.168206   0.103002
# 4    PCA_5_bins    0.059293    0.135321   0.058225
# 5    PCA_6_bins    0.072149    0.130227   0.037160
# 6    PCA_7_bins    0.077675    0.147297   0.055130
# 7    PCA_8_bins    0.082454    0.165957   0.074980

# %%
this_steps = [
        (
            "channels_filtering",
            ChannelExtraction(significant_channels),
        ),
        ("spatial_filter_preprocessing", SpatialFilterPreprocessing()),
        (
            "spatial_filter",
            PCA(n_components=3, random_state=random_state),
        )]

pre_processing_pipeline = Pipeline(steps=this_steps)

# perform pre-processing
pre_processed_pipeline = pre_processing_pipeline.fit(X_train)
# Out:
# EXTRACTION (108,)

# %%
pca_components = pre_processed_pipeline['spatial_filter'].components_

# %%
from numpy import save
save('pca_components_static_non_averaged.npy', pca_components)

# %% [markdown]
# ---

# %%
results_mae_15_df

# %%
results_mae_15_df.to_pickle(
    "../data/regression_PCA_sf15_fex8_mae" + dataset_name + ".pkl"
)

# %%
results_R_D_df

# %%
results_R_D_df.to_pickle(
    "../data/regression_PCA_sf15_fex8_mae_R-D_" + dataset_name + ".pkl"
)

# %%
results_D_df

# %%
results_A_df

# %%
results_A_df.to_pickle(
    "../data/regression_PCA_sf15_fex8_mae_A_" + dataset_name + ".pkl"
)

# %%
results_D_df.to_pickle(
    "../data/regression_PCA_sf15_fex8_mae_D_" + dataset_name + ".pkl"
)

# %%
results_S_df

# %%
results_S_df.to_pickle(
    "../data/regression_PCA_sf15_fex8_r2_S_" + dataset_name + ".pkl"
)

# %%
results_S_df
